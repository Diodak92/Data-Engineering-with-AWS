# %%
import boto3
import configparser
import pandas as pd

# %%
# Load configuration
config = configparser.ConfigParser()
config.read('dwh.cfg')

LOG_DATA=config.get("S3","LOG_DATA")
LOG_JSONPATH=config.get("S3","LOG_JSONPATH")
SONG_DATA=config.get("S3","SONG_DATA")

def list_objects_v2(bucket : str, prefix : str = None) -> pd.DataFrame:
    """
    List objects in an S3 bucket with a given prefix.
    """
    s3 = boto3.client('s3')
    response = s3.list_objects_v2(Bucket=bucket, Prefix=prefix)
    return pd.DataFrame(response['Contents'])

def get_s3_object(bucket : str, key : str) -> pd.DataFrame:
    """
    Get an object from S3 and return it as a DataFrame.
    """
    s3 = boto3.client('s3')
    obj = s3.get_object(Bucket=bucket, Key=key)
    return obj['Body']

# %% [markdown]
# ### List log data files

# %%
# List objects in the S3 bucket
bucket_name = LOG_DATA.split('/')[2]
list_objects_v2(bucket_name, 'log_data')
# Out:
#                                         Key              LastModified  \
# 0                                 log_data/ 2019-04-17 12:02:38+00:00
# 1   log_data/2018/11/2018-11-01-events.json 2019-04-17 12:03:13+00:00
# 2   log_data/2018/11/2018-11-02-events.json 2019-04-17 12:03:13+00:00
# 3   log_data/2018/11/2018-11-03-events.json 2019-04-17 12:03:13+00:00
# 4   log_data/2018/11/2018-11-04-events.json 2019-04-17 12:03:13+00:00
# 5   log_data/2018/11/2018-11-05-events.json 2019-04-17 12:03:13+00:00
# 6   log_data/2018/11/2018-11-06-events.json 2019-04-17 12:03:13+00:00
# 7   log_data/2018/11/2018-11-07-events.json 2019-04-17 12:03:13+00:00
# 8   log_data/2018/11/2018-11-08-events.json 2019-04-17 12:03:13+00:00
# 9   log_data/2018/11/2018-11-09-events.json 2019-04-17 12:03:13+00:00
# 10  log_data/2018/11/2018-11-10-events.json 2019-04-17 12:03:13+00:00
# 11  log_data/2018/11/2018-11-11-events.json 2019-04-17 12:03:13+00:00
# 12  log_data/2018/11/2018-11-12-events.json 2019-04-17 12:03:13+00:00
# 13  log_data/2018/11/2018-11-13-events.json 2019-04-17 12:03:13+00:00
# 14  log_data/2018/11/2018-11-14-events.json 2019-04-17 12:03:13+00:00
# 15  log_data/2018/11/2018-11-15-events.json 2019-04-17 12:03:13+00:00
# 16  log_data/2018/11/2018-11-16-events.json 2019-04-17 12:03:13+00:00
# 17  log_data/2018/11/2018-11-17-events.json 2019-04-17 12:03:13+00:00
# 18  log_data/2018/11/2018-11-18-events.json 2019-04-17 12:03:13+00:00
# 19  log_data/2018/11/2018-11-19-events.json 2019-04-17 12:03:13+00:00
# 20  log_data/2018/11/2018-11-20-events.json 2019-04-17 12:03:13+00:00
# 21  log_data/2018/11/2018-11-21-events.json 2019-04-17 12:03:13+00:00
# 22  log_data/2018/11/2018-11-22-events.json 2019-04-17 12:03:13+00:00
# 23  log_data/2018/11/2018-11-23-events.json 2019-04-17 12:03:13+00:00
# 24  log_data/2018/11/2018-11-24-events.json 2019-04-17 12:03:13+00:00
# 25  log_data/2018/11/2018-11-25-events.json 2019-04-17 12:03:13+00:00
# 26  log_data/2018/11/2018-11-26-events.json 2019-04-17 12:03:13+00:00
# 27  log_data/2018/11/2018-11-27-events.json 2019-04-17 12:03:13+00:00
# 28  log_data/2018/11/2018-11-28-events.json 2019-04-17 12:03:13+00:00
# 29  log_data/2018/11/2018-11-29-events.json 2019-04-17 12:03:13+00:00
# 30  log_data/2018/11/2018-11-30-events.json 2019-04-17 12:03:13+00:00
#
#                                   ETag    Size StorageClass
# 0   "d41d8cd98f00b204e9800998ecf8427e"       0     STANDARD
# 1   "21bae37b41c56b66973312a07322b5e4"    7151     STANDARD
# 2   "c726b249410a532cce10fa166ce8616c"   83585     STANDARD
# 3   "696af259d3203446b846de7937b5810c"   54084     STANDARD
# 4   "3d10cad17e2279b29da00756a885659b"   85671     STANDARD
# 5   "5055eafc2dcd43d7a39486683857da01"  189295     STANDARD
# 6   "c0594b7fad6851d5d47650caffa48ea0"   85373     STANDARD
# 7   "e6b529f7305fe26eca5e5ef85aa2e014"   97519     STANDARD
# 8   "8a037906ea14c4bd6ea23e2d5333aa13"  102218     STANDARD
# 9   "ea4f34c437d8caa2634ff98bef315f2a"  134804     STANDARD
# 10  "272eeb15e546f06009fb67600f426e0e"   44076     STANDARD
# 11  "0a9258f19b565369bd89d87608530782"   43711     STANDARD
# 12  "d72f8a08de7bd2d784d507956761e77e"   99854     STANDARD
# 13  "03961d37b48699e3ff408fa5f01d45c4"  186826     STANDARD
# 14  "c8013941ab0400803119f2c37b3e2708"  217264     STANDARD
# 15  "ff98067209187a8963a2c0c18967f54f"  243143     STANDARD
# 16  "d381c80c292b1e15c728bef591b40eb6"  175491     STANDARD
# 17  "1d117c1dc8a530439eea91c79a9a11a2"   66164     STANDARD
# 18  "f7845257f768de6d10ad3f43f8b2d6ba"   75763     STANDARD
# 19  "e2fb42cee2c647beab13944f1452b8d8"  150798     STANDARD
# 20  "28597cac7420f7260cc5ee8fdcb1fa59"  174991     STANDARD
# 21  "5b811a1ee64982e60eb90234011227e8"  242588     STANDARD
# 22  "0e02b7971550d80899ace62a56e96776"   46181     STANDARD
# 23  "8c8f106d950a9c7768f8b2c5b63cb597"  138647     STANDARD
# 24  "57c55089602d67e0421a214a1942adf6"  170219     STANDARD
# 25  "354ce3dc842cc3a5c5c205574e31f082"   26214     STANDARD
# 26  "62c3cf125b4c51111858c104b48ec56f"  123576     STANDARD
# 27  "38fdb9ddad08ea8d38761281bd3e797f"  141625     STANDARD
# 28  "958bb973e883807f00a35801b9191c7f"  202910     STANDARD
# 29  "b83ce60beda7021c6ce1c05385bba969"  168646     STANDARD
# 30  "350823c28fb33b855b08c3940f16d8d2"  177211     STANDARD

# %%
# Get sample data from S3
get_s3_object(bucket_name, 'log_data/2018/11/2018-11-08-events.json')

# %% [markdown]
# ### List log files

# %%
list_objects_v2(bucket_name, 'log_json_path')
# Out:
#                   Key              LastModified  \
# 0  log_json_path.json 2019-04-02 16:58:44+00:00
#
#                                  ETag  Size StorageClass
# 0  "6ee138e5504cffd12cded1323dfbd6a4"   456     STANDARD

# %%
# Get sample data from S3
pd.read_json(get_s3_object(bucket_name, 'log_json_path.json'))
# Out:
#              jsonpaths
# 0          $['artist']
# 1            $['auth']
# 2       $['firstName']
# 3          $['gender']
# 4   $['itemInSession']
# 5        $['lastName']
# 6          $['length']
# 7           $['level']
# 8        $['location']
# 9          $['method']
# 10           $['page']
# 11   $['registration']
# 12      $['sessionId']
# 13           $['song']
# 14         $['status']
# 15             $['ts']
# 16      $['userAgent']
# 17         $['userId']

# %% [markdown]
# ### List song data

# %%
list_objects_v2(bucket_name, 'song_data')
# Out:
#                                          Key              LastModified  \
# 0                                 song_data/ 2019-04-17 03:12:52+00:00
# 1    song_data/A/A/A/TRAAAAK128F9318786.json 2019-04-17 03:20:41+00:00
# 2    song_data/A/A/A/TRAAAAV128F421A322.json 2019-04-17 03:20:41+00:00
# 3    song_data/A/A/A/TRAAABD128F429CF47.json 2019-04-17 03:20:41+00:00
# 4    song_data/A/A/A/TRAAACN128F9355673.json 2019-04-17 03:20:41+00:00
# ..                                       ...                       ...
# 995  song_data/A/B/R/TRABRFP128F42B7B7A.json 2019-04-17 03:20:51+00:00
# 996  song_data/A/B/R/TRABRHL128F4274DB0.json 2019-04-17 03:20:51+00:00
# 997  song_data/A/B/R/TRABRHT12903CF274F.json 2019-04-17 03:20:51+00:00
# 998  song_data/A/B/R/TRABRJZ12903CE9196.json 2019-04-17 03:20:51+00:00
# 999  song_data/A/B/R/TRABRLW128F930321D.json 2019-04-17 03:20:51+00:00
#
#                                    ETag  Size StorageClass
# 0    "d41d8cd98f00b204e9800998ecf8427e"     0     STANDARD
# 1    "48e073986610c4997c26f8a394b8fd6e"   225     STANDARD
# 2    "fc84ae8a04e72df00ac2a25218f14a18"   284     STANDARD
# 3    "df6d7bb1676146a859af35cb3468e8dd"   249     STANDARD
# 4    "86f1807dd1cfa21826cf374c6c2625a7"   243     STANDARD
# ..                                  ...   ...          ...
# 995  "977f88d5aeca9208780bbbf30dae214e"   257     STANDARD
# 996  "ff3e142ed97c25a461133c67c16d15d0"   241     STANDARD
# 997  "12e3bc2bfbaf6ea0f224798647244890"   255     STANDARD
# 998  "3b09e7cd7d50350f0376a544ff680fec"   234     STANDARD
# 999  "955df2fdc71080988a50a70fa382b520"   238     STANDARD
#
# [1000 rows x 5 columns]

# %%
# Get sample data from S3
(get_s3_object(bucket_name, 'song_data/A/A/A/TRAAABD128F429CF47.json'), inlines=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 # Get sample data from S3
# ----> 2 pd.read_json(get_s3_object(bucket_name, 'song_data/A/A/A/TRAAABD128F429CF47.json'), inlines=0)
#
# TypeError: read_json() got an unexpected keyword argument 'inlines'
